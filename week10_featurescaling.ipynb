# %% [markdown]
# <a href="https://colab.research.google.com/github/Tbaraka/Supervised-ML/blob/main/week10_featurescaling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectPercentile
iris=load_iris()
X_TRAIN,X_TEST,Y_TRAIN,Y_TEST=train_test_split(iris.data,iris.target,random_state=0,test_size=0.5)
select=SelectPercentile(percentile=50).fit(X_TRAIN,Y_TRAIN)
X_TRAIN_SELECT=select.transform(X_TRAIN)
print(X_TRAIN.shape)
print(X_TRAIN_SELECT.shape)
# Out:
# (75, 4)
# (75, 2)
