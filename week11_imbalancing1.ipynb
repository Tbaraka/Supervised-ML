# %% [markdown]
# <a href="https://colab.research.google.com/github/Tbaraka/Supervised-ML/blob/main/week11_imbalancing1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0, test_size=0.5)
#labeling cancer malignant as label1
y=np.where(y==0,1,0)

# %%
LR =LogisticRegression(max_iter=10000).fit(X_train,y_train)
print("Training Accuracy:" ,LR.score(X_train,y_train))
print("Testing Accuracy:" ,LR.score(X_test,y_test))
# Out:
# Training Accuracy: 0.9612676056338029
# Testing Accuracy: 0.9578947368421052

# %%
from imblearn.over_sampling import RandomOverSampler,SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %%
#RANDOM OVERSAMPLING
ROS = RandomOverSampler(random_state=42)
#you only banace the training data not the test
X_ROS,y_ROS= ROS.fit_resample(X_train,y_train)

LR =LogisticRegression(max_iter=10000).fit(X_train,y_train)
print("Training Accuracy:" ,LR.score(X_ROS,y_ROS))
print("Testing Accuracy:" ,LR.score(X_test,y_test))
# Out:
# Training Accuracy: 0.9624277456647399
# Testing Accuracy: 0.9578947368421052

# %%
SM =SMOTE(random_state=42)
#you only banace the training data not the test
X_SM,y_SM= SM.fit_resample(X_train,y_train)

LR =LogisticRegression(max_iter=10000).fit(X_train,y_train)
print("Training Accuracy:" ,LR.score(X_SM,y_SM))
print("Testing Accuracy:" ,LR.score(X_test,y_test))
# Out:
# Training Accuracy: 0.9624277456647399
# Testing Accuracy: 0.9578947368421052

# %%
ru=RandomUnderSampler(random_state=42)
#you only banace the training data not the test
X_ru,y_ru= ru.fit_resample(X_train,y_train)

LR =LogisticRegression(max_iter=10000).fit(X_train,y_train)
print("Training Accuracy:" ,LR.score(X_ru,y_ru))
print("Testing Accuracy:" ,LR.score(X_test,y_test))
# Out:
# Training Accuracy: 0.954954954954955
# Testing Accuracy: 0.9578947368421052
